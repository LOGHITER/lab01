# %%
import pandas as pd;
import matplotlib.pyplot as plt;
import numpy as np;
import seaborn as sns;

sr = pd.read_csv('data_search_rand.csv')
sfa = pd.read_csv('data_search_from_array.csv')
bsr = pd.read_csv('data_binar_search_rand.csv')
bsfa = pd.read_csv('data_binar_search_from_array.csv')
sum = pd.read_csv('data_sum.csv')
sumR = pd.read_csv('data_sum_rand.csv')
qsum = pd.read_csv('data_QSumSearch_rand.csv')
data = pd.read_csv('data.csv')

#sum.plot.scatter(x='N', y='T')
sr.plot.scatter(x = 'N', y = 'T1', label = 'O(n) search random int, unsorted array')
sfa.plot.scatter(x = 'N', y = 'T1', label = 'O(n) search random index, unsorted array')
bsr.plot.scatter(x = 'N', y = 'T1', label = 'O(logn) search random int')
bsfa.plot.scatter(x = 'N', y = 'T1', label = 'O(logn) search random index')

data.plot.scatter(x = 'N', y = 'T1', label = 'O(n) search random index, sorted array, same data')
data.plot.scatter(x = 'N', y = 'T2', label = 'O(logn) search, random index, same data')

sum.plot.scatter(x = 'N', y = 'T1', label = 'O($n^2$) sum search, random index, unsorted array')
sumR.plot.scatter(x = 'N', y = 'T1', label = 'O($n^2$) sum search, random int, unsorted')
# Out:
# <Axes: xlabel='N', ylabel='T1'>
