# %%
import pandas as pd;
import matplotlib.pyplot as plt;
import numpy as np;
import seaborn as sns;

data = pd.read_csv('data_binar_search.csv')
data2 = pd.read_csv('data_search.csv')

data.plot.scatter(x = 'N', y = 'T')
data2.plot.scatter(x='N', y = 'T')
# Out:
# <Axes: xlabel='N', ylabel='T'>
